# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/hitendraparanjpe/Downloads/DSData-master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # Column description and understanding
#
# The scoring is based on ones perception about how one pictures his perfect life and ones current state with respect to the ideal life on a scale of 0-10 with 0 being the worst and 10 being the best.
#
#
# 1. Country - Name of the Country
#
#
# 2. Region - Continent or the Region in which the country is located
#
#
# 3. Happiness Rank - Rank of the Country based on the happiness score
#
#
# 4. Happiness Score - Measure of the happiness the people
#
#
# 5. Economy (GDP per Capita) - It is the measure of GDP per capita. It is a measure of determining the Purchasing Power Parity.
#
#
# 6. Family - It is a measure of Support from Family, Relatives and Friends during difficult situations.
#
#
# 7. Health (Life Expectancy) - Measure of health parameters and longetivity of life.
#
#
# 8. Freedom - It is a measure of Freedom of choices.
#
#
# 9. Trust (Government Corruption) - It is a measure of Trust in the government. It is a measure of degree of corruption in the governement.
#
#
# 10. Generosity - It is a measure of Generosity or Charity by an Individual of the Country.
#
#
# 11. Dystopia Residual - It is the measure of unexplained parameters of the Happiness score.

# %% [markdown]
# In this Happiness Score is the Label.
#
# Country and Region are not inputs and are just for recognition.
#
# Happiness rank is the rank based on Happiness Score. Hence it is neither a Feature nor a Label.
#
# Following are the Features of the Data Set:
#
# 1. Economy
# 2. Family
# 3. Health
# 4. Freedom
# 5. Trust
# 6. Generosity

# %%
#Let's check if the data set has null values

df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# Let's drop the unwanted columns:

df = df.drop(columns=['Country','Region','Happiness Rank','Standard Error','Dystopia Residual'])

# %%
df.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# 2     0.34139
# 3     0.34699
# 4     0.45811

# %% [markdown]
# # Exploratory Data Analytics (EDA)

# %%
# Let's check the heat map to understand the Co-relation

plt.figure(figsize=(15,8))

sns.heatmap(df.corr(),annot = True, linewidths = 0.5, linecolor = "Black")
# Out:
# <AxesSubplot:>

# %% [markdown]
# All the columns generally have positive corelation with the Happiness Score.
#
# 1. Max Corelation: GDP has the highest Corelation with Happiness Score (78%) followed by Family (74%) and Health (72%)
#
# 2. Min Corelation: Generosity has least corelation with Happiness Score (18%).
#
# Health and Economy seems to have strong Co-relation with each other. This seems acceptable, since developed countries have better GDP per Capita and better health care facilities. Hence, even after strong corelation, we will not consider it to be Multi Collinearity and will not drop any Feature. We will continue with all the 6 Features.

# %%
plt.figure(figsize = (12,3))
sns.boxplot(df['Economy (GDP per Capita)'])
plt.tight_layout()

# %% [markdown]
# This shows that Economy data has no outliers.

# %%
plt.figure(figsize = (12,3))
sns.boxplot(df['Family'])
plt.tight_layout()

# %% [markdown]
# Family data has a few outliers. The data seems to be right skewed.

# %%
plt.figure(figsize = (12,3))
sns.boxplot(df['Health (Life Expectancy)'])
plt.tight_layout()

# %% [markdown]
# Health does not seems to have outliers. The data is slightly Right Skewed.

# %%
plt.figure(figsize = (12,3))
sns.boxplot(df['Freedom'])
plt.tight_layout()

# %% [markdown]
# Freedom does not have outliers and the data seems to be Right Skewed.

# %%
plt.figure(figsize = (12,3))
sns.boxplot(df['Trust (Government Corruption)'])
plt.tight_layout()

# %% [markdown]
# Trust Data seems to have a lot of outliers. We will need to look at this data before proceeding. The Data set seems to be Left Skewed.

# %%
plt.figure(figsize = (12,3))
sns.boxplot(df['Generosity'])
plt.tight_layout()

# %% [markdown]
# Geneorsity seems to have a very few outliers.

# %%
plt.figure(figsize=(20,25), facecolor = "white")

plotnumber = 1

for column in df:
    if plotnumber<=7:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize = 20)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# There is some skewness in the data set, and also there are some outliers. However, since the number of data points are less, and all the features have strong co-relation with the label, we will not drop outliers.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
lr = LinearRegression()

# %%
x = df.drop(columns=['Happiness Score'])
x
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity
# ...

# %%
y = df['Happiness Score']
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 355)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
met = metrics.mean_squared_error(y_pred,y_test)
met
# Out:
# 0.27979032265989634

# %%
print(lr.coef_)
# Out:
# [0.85998136 1.16964129 1.08413659 1.42634599 1.2011602  0.49433537]
